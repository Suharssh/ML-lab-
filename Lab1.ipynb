# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (20.0, 10.0)

df = pd.read_csv("C:/Users/student/Downloads/headbrain.csv")
print(df.shape)
df.head()
# Out:
# (237, 4)
#    Gender  Age Range  Head Size(cm^3)  Brain Weight(grams)
# 0       1          1             4512                 1530
# 1       1          1             3738                 1297
# 2       1          1             4261                 1335
# 3       1          1             3777                 1282
# 4       1          1             4177                 1590

# %%
X = df['Head Size(cm^3)'].values
Y = df['Brain Weight(grams)'].values

# %%
mean_X = np.mean(X)
mean_Y = np.mean(Y)

n = len(X)

numer = 0
denom = 0

for i in range(n):
    numer+=(X[i]-mean_X)*(Y[i]-mean_Y) #finding the sum of residues
    denom+=(X[i]-mean_X)**2
    
b1 = numer/denom
b0 = mean_Y - b1*(mean_X) #intercept formula

print(b1,b0) #regression coefficients
# Out:
# 0.26342933948939945 325.57342104944223

# %%
max_x = np.max(X)+100
min_x = np.min(X)-100

x = np.linspace(min_x,max_x,1000)
y = b0+b1*x

plt.plot(x,y,color = 'red',label = 'Regression line')


plt.scatter(X, Y, c='green', label='Data points')

plt.xlabel('Head Size in cm3')
plt.ylabel('Brain Weight in grams')
plt.legend()
plt.show()
